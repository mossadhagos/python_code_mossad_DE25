# %%
pip install matplotlib
# Out:
# /Users/lillmossi/Documents/github/python_code_mossad_DE25/.venv/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Lecture 12 - matplotlib
# - in this cures, focus on the distinction between two ways  of writing matålotlib codes
# - in this cures, focus on the components of matplotlib figure

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate some data
x = np.linspace(-5, 10, 100)
x

# %%
# generate data f
f  = np.sin(x)
f

# %% [markdown]
# ### the first approach - functional/matplotlib

# %%
plt.figure()
plt.plot(x,f)
plt.title("sin(x)")
plt.xlabel("Y")
plt.ylabel("X")
# Out:
# Text(0, 0.5, 'X')

# %% [markdown]
# ### the scond approach - oop

# %%
fig = plt.figure() # creat one figuree 
ax = plt.axes () # on the figure crate an axe
ax.plot(x, f) # on the axe, create a plot 
ax.set(xlim= (-10,10), ylim=(-5,5), xlabel="x", ylabel="y") # continue modify the axe object in difrenen aspectes
# Out:
# [(-10.0, 10.0), (-5.0, 5.0), Text(0.5, 0, 'x'), Text(0, 0.5, 'y')]
